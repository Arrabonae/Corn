# %%
import pandas as pd
import numpy as np

df = pd.read_csv('weather_2017.csv', header=None, sep=',')
df.columns = ['Station identifier', 'Date', 'Observation type', 'Observation value', 'Measurement Flag', 'Quality Flag','Source Flag', 'Observation Time']
df.head()
# Out:
#   Station identifier      Date Observation type  Observation value  \
# 0        US1ILMG0006  20170101             PRCP                  0
# 1        US1ILMG0006  20170101             SNOW                  0
# 2        CA1MB000296  20170101             PRCP                  0
# 3        US1ILCP0081  20170101             PRCP                  0
# 4        US1ILCP0081  20170101             SNOW                  0
#
#   Measurement Flag Quality Flag Source Flag  Observation Time
# 0              NaN          NaN           N               NaN
# 1              NaN          NaN           N               NaN
# 2              NaN          NaN           N               NaN
# 3              NaN          NaN           N               NaN
# 4              NaN          NaN           N               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34795541 entries, 0 to 34795540
# Data columns (total 8 columns):
# Station identifier    object
# Date                  int64
# Observation type      object
# Observation value     int64
# Measurement Flag      object
# Quality Flag          object
# Source Flag           object
# Observation Time      float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 2.1+ GB

# %%
df[df['Observation type']=='TMAX'].head()
# Out:
#    Station identifier      Date Observation type  Observation value  \
# 6         ASN00015643  20170101             TMAX                274
# 16        ASN00085296  20170101             TMAX                217
# 20        ASN00085280  20170101             TMAX                215
# 24        ASN00040209  20170101             TMAX                293
# 74        CA005030984  20170101             TMAX               -109
#
#    Measurement Flag Quality Flag Source Flag  Observation Time
# 6               NaN          NaN           a               NaN
# 16              NaN          NaN           a               NaN
# 20              NaN          NaN           a               NaN
# 24              NaN          NaN           a               NaN
# 74              NaN          NaN           C               NaN

# %%
df.to_csv('weather_2017.csv')

# %%
df = pd.read_csv('weather_2017.csv')
df.head()
# Out:
#    Unnamed: 0 Station identifier      Date Observation type  \
# 0           0        US1ILMG0006  20170101             PRCP
# 1           1        US1ILMG0006  20170101             SNOW
# 2           2        CA1MB000296  20170101             PRCP
# 3           3        US1ILCP0081  20170101             PRCP
# 4           4        US1ILCP0081  20170101             SNOW
#
#    Observation value Measurement Flag Quality Flag Source Flag  \
# 0                  0              NaN          NaN           N
# 1                  0              NaN          NaN           N
# 2                  0              NaN          NaN           N
# 3                  0              NaN          NaN           N
# 4                  0              NaN          NaN           N
#
#    Observation Time
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
